# %% [markdown]
# **<font color=skyblue>機器學習常見的三種監督式分類器（Supervised Classification）</font>**
#
# 分類器（Classifiers）
# - 多元羅吉斯回歸 Multinomial Logistic Regression (LR)
# - 支援向量機 Support Vector Machine (SVM)
# - 類神經網路 artificial Neural Network (ANN)
#
# 分類資料
# - wine.xlsx
# - groups: 13
# - original data vs. principal components
# - split into training data and testing data
#
#
#
# 參考講義：
# https://ntpuccw.blog/sml-lesson-8-%e6%b7%ba%e5%ba%a6%e6%a9%9f%e5%99%a8%e5%ad%b8%e7%bf%92%ef%bc%9a%e5%88%86%e9%a1%9e%e5%99%a8%e7%9a%84%e5%8e%9f%e7%90%86%e8%88%87%e8%a9%95%e6%af%94%e5%af%a6%e9%a9%97/
# <hr>

# %% [markdown]
# <font color=yellow>Import Basic Packages</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# <font color=yellow>資料準備</font>

# %%
# Read data
df = pd.read_excel('data/Wine.xlsx')
X = np.array(df.iloc[:, :-1]) # 排除最後一欄標籤 N x p
y = np.array(df.iloc[:, -1]) # label N x 1

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30)

# Standardize data
scaler = StandardScaler()
X_train_ = scaler.fit_transform(X_train)
X_test_ = scaler.transform(X_test)

# print training and testing data shapes
print("Training data shape:", X_train_.shape)
print("Testing data shape:", X_test_.shape)
# Out:
# Training data shape: (124, 13)
# Testing data shape: (54, 13)

# %% [markdown]
# <font color=yellow>LogisticRegression on original data</font>
#
# - 了解 LogisticRegression 的重要參數對結果的影響，譬如 C：Inverse of regularization strength。
# - 嘗試不同的演算法 solvers：{‘lbfgs’, ‘liblinear’, ‘newton-cg’, ‘newton-cholesky’, ‘sag’, ‘saga’}.
# - 了解對評估分群能力的指標： precision, recall, f1-score
#
# precision = $\frac{TP}{TP+FP}$,
# recall = $\frac{TP}{TP+FN}$,
# F1-score = $2\frac{precision\cdot recall}{precision + recall}$

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

opts = dict(C=1.0, tol = 1e-6, max_iter = int(1e6), verbose=1)
solver = 'lbfgs'  # 'lbfgs' is the default
# solver = 'liblinear'
# solver = 'newton-cg'
# clf_original = LogisticRegression(solver = 'lbfgs', tol = 1e-6, max_iter = int(1e6), verbose=True)
clf_LR_original = LogisticRegression(solver = solver, **opts)
clf_LR_original.fit(X_train_, y_train) # input data must be (n_samples x n_features)
y_pred = clf_LR_original.predict(X_test_) # predict class labels for samples in X_test_
# print training score
print(f"Training score = {accuracy_score(y_train, clf_LR_original.predict(X_train_)):.2%}\n")
# print testing score
print(f"Testing score = {accuracy_score(y_test, y_pred):.2%}\n")
print(f"Testing score = {clf_LR_original.score(X_test_, y_test):.2%}\n")
print("Classification report: Original data\n")
print(classification_report(y_test, y_pred))
# Out:
# Training score = 100.00%
#
# Testing score = 94.44%
#
# Testing score = 94.44%
#
# Classification report: Original data
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.96      0.98        25
#            2       0.91      0.95      0.93        21
#            3       0.88      0.88      0.88         8
#
#     accuracy                           0.94        54
#    macro avg       0.93      0.93      0.93        54
# weighted avg       0.95      0.94      0.94        54
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %% [markdown]
# <font color=yellow>LogisticRegression on principal components</font>

# %%
from sklearn.decomposition import PCA

q = 2
pca = PCA(n_components = q).fit(X_train_)
Z_train = pca.transform(X_train_)
Z_test = pca.transform(X_test_)
opts = dict(tol = 1e-6, max_iter = int(1e6), verbose=1)
solver = 'lbfgs'  # 'lbfgs' is default; 
# solver = 'liblinear'
# solver = 'newton-cg'
# clf_LR = LogisticRegression(solver = 'lbfgs', tol = 1e-6, max_iter = int(1e6), verbose=1)
clf_PCA = LogisticRegression(solver = solver, **opts)
clf_PCA.fit(Z_train, y_train) # input data must be (n_samples x n_features)
y_pred = clf_PCA.predict(Z_test)

print(f"Training score: {accuracy_score(y_train, clf_PCA.predict(Z_train)):.2%}\n")
# print testing score
print(f"Testing score: {clf_PCA.score(Z_test, y_test):.2%}\n")
print(f"Classification report: PCA with {q} components\n")
print(classification_report(y_test, y_pred))
# Out:
# Training score: 97.58%
#
# Testing score: 92.59%
#
# Classification report: PCA with 2 components
#
#               precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96        25
#            2       0.90      0.90      0.90        21
#            3       0.88      0.88      0.88         8
#
#     accuracy                           0.93        54
#    macro avg       0.91      0.91      0.91        54
# weighted avg       0.93      0.93      0.93        54
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %% [markdown]
# <hr>
# <font color=orange>練習：製作副程式以方便比較 original data vs principal components 的測試結果。譬如，將結果安排在同一個表格。
# <hr>

# %%
# write def code to do logistic regression with data  and return training and testing scores
def logistic_regression(X_train, y_train, X_test, y_test, solver='lbfgs'):
    opts = dict(C=1.0, tol = 1e-6, max_iter = int(1e6), verbose=1)
    clf = LogisticRegression(solver = solver, **opts)
    clf.fit(X_train, y_train) # input data must be (n_samples x n_features)
    y_pred = clf.predict(X_test) # predict class labels for samples in X_test
    training_score = accuracy_score(y_train, clf.predict(X_train))
    testing_score = accuracy_score(y_test, y_pred)
    return training_score, testing_score

# %%
# 方法一、
# use original data
training_score, testing_score = logistic_regression(X_train_, y_train, X_test_, y_test)
print('Original data\n')
print(f"Training score: {training_score:.2%}\n")
print(f"Testing score: {testing_score:.2%}\n")
# use PCA data
training_score, testing_score = logistic_regression(Z_train, y_train, Z_test, y_test)
print('PCA data\n')
print(f"Training score: {training_score:.2%}\n")
print(f"Testing score: {testing_score:.2%}\n")

# 方法二、
# combine the results into a dataframe
results = pd.DataFrame({
    'Data': ['Original', 'PCA'],
    'Training Score': [logistic_regression(X_train_, y_train, X_test_, y_test)[0],
                       logistic_regression(Z_train, y_train, Z_test, y_test)[0]],
    'Testing Score': [logistic_regression(X_train_, y_train, X_test_, y_test)[1],
                      logistic_regression(Z_train, y_train, Z_test, y_test)[1]]
})
# need to print results to decimal to 2 places
results['Training Score'] = results['Training Score'].map('{:.2%}'.format)
results['Testing Score'] = results['Testing Score'].map('{:.2%}'.format)
print(results)
# Out:
# Original data
#
# Training score: 100.00%
#
# Testing score: 94.44%
#
# PCA data
#
# Training score: 97.58%
#
# Testing score: 92.59%
#
#        Data Training Score Testing Score
# 0  Original        100.00%        94.44%
# 1       PCA         97.58%        92.59%
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %% [markdown]
# <font color=yellow>Use LogisticRegressionCV: Logistic Regression + Cross Validation</font>
#
# - Cross Validation: performs cross‑validated hyperparameter tuning over Cs and l1_ratios and then refits the best model.
# - Cs: the inverse of regularization strength.
# - li_ratio: mixing parameter between L1 and L2 penalties.

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import accuracy_score

# For solver='lbfgs', the default penalty is L2,
# so l1_ratios / l1_ratio_ are not used here.
opts = dict(tol=1e-6, max_iter=int(1e6), verbose=0)
solver = 'lbfgs'  # 'lbfgs' is the default
# solver = 'liblinear'
# solver = 'newton-cg'
Cs = np.logspace(-4, 4, 20)

clf_originalCV = LogisticRegressionCV(solver=solver, Cs=Cs, **opts)
clf_originalCV.fit(X_train_, y_train)
y_pred = clf_originalCV.predict(X_test_)

# print training score
print(f"Training score = {accuracy_score(y_train, clf_originalCV.predict(X_train_)):.2%}\n")
# print testing score
print(f"Testing score = {accuracy_score(y_test, y_pred):.2%}\n")
print(f"Testing score = {clf_originalCV.score(X_test_, y_test):.2%}\n")
print("Classification report: Original data with CV\n")
print(classification_report(y_test, y_pred))
# print the best C value found by CV
print(f"Best C value found by CV: {clf_originalCV.C_[0]:.4f}\n")
# l1_ratio is only relevant for penalty='elasticnet' with solver='saga'
print("Best l1_ratio value found by CV: N/A for L2 penalty with solver='lbfgs'\n")
# Out:
# Training score = 100.00%
#
# Testing score = 94.44%
#
# Testing score = 94.44%
#
# Classification report: Original data with CV
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.96      0.98        25
#            2       0.91      0.95      0.93        21
#            3       0.88      0.88      0.88         8
#
#     accuracy                           0.94        54
#    macro avg       0.93      0.93      0.93        54
# weighted avg       0.95      0.94      0.94        54
#
# Best C value found by CV: 0.2336
#
# Best l1_ratio value found by CV: N/A for L2 penalty with solver='lbfgs'

# %% [markdown]
# <hr>
# <font color=yellow>SVM on original data</font>
#
# - 了解 SVC 的重要參數對結果的影響，譬如
#     - C：the inverse of the regularization strength。
#     - decision function shape: ovr (one vs rest), ovo (one vs one)
# - 嘗試不同的核 kernel: linear, poly, rbf, sigmoid, precomputed

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import classification_report

C = 1 # SVM regularization parameter
opts = dict(C = C, tol = 1e-6, max_iter = int(1e6), \
            decision_function_shape = 'ovo', verbose=1)

clf_svm = SVC(kernel='linear', **opts)
# clf_svm = SVC(kernel='rbf', gamma=0.2, **opts)
# clf_svm = SVC(kernel='poly', degree=3, gamma='auto', **opts)
# clf_svm = LinearSVC(**opts) # one vs the rest
clf_svm.fit(X_train_, y_train)
predictions = clf_svm.predict(X_test_)
print(classification_report(y_test, predictions))
# Out:
# [LibSVM]..*.*
# optimization finished, #iter = 265
# obj = -1.503712, rho = 0.785233
# nSV = 9, nBSV = 0
# *
# optimization finished, #iter = 55
# obj = -0.194333, rho = -0.070819
# nSV = 6, nBSV = 0
# ......*..*
# optimization finished, #iter = 723
# obj = -1.510710, rho = -1.214302
# nSV = 11, nBSV = 0
# Total nSV = 23
#               precision    recall  f1-score   support
#
#            1       1.00      0.96      0.98        25
#            2       0.91      0.95      0.93        21
#            3       0.88      0.88      0.88         8
#
#     accuracy                           0.94        54
#    macro avg       0.93      0.93      0.93        54
# weighted avg       0.95      0.94      0.94        54

# %% [markdown]
# <hr>
# <font color=yellow>ANN on original data</font>
#
# 關注參數的選擇：
# - 隱藏層 hidden_layers
# - 激活函數 activation function: identity, logistic, tanh, relu (default)
# - 演算法 solvers: lbfgs, sgd, adam (default)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# hidden_layers = (512,) # one hidden layer
# activation = 'relu' # the default
hidden_layers = (20,) # one hidden layer
activation = 'logistic' # the default
opts = dict(hidden_layer_sizes = hidden_layers, verbose = True, \
        activation = activation, tol = 1e-6, max_iter = int(1e6))
# solver = 'sgd' # not efficient, need more tuning
# solver = 'lbfgs' # not suitable here
solver = 'adam' # default solver
clf_MLP = MLPClassifier(solver = solver, **opts) 
clf_MLP.fit(X_train_, y_train)
predictions = clf_MLP.predict(X_test_)
# print("accuracy for tested data: {:.2f}%".format(100*np.mean(y_test_hat == y_test)))
print("accuracy for test data: {:.2f}%".format(100*clf_MLP.score(X_test, y_test)))
print(classification_report(y_test, predictions))
# Out:
# Iteration 1, loss = 1.12571094
# Iteration 2, loss = 1.12063998
# Iteration 3, loss = 1.11567117
# Iteration 4, loss = 1.11080543
# Iteration 5, loss = 1.10604238
# Iteration 6, loss = 1.10137965
# Iteration 7, loss = 1.09681303
# Iteration 8, loss = 1.09233797
# Iteration 9, loss = 1.08795064
# Iteration 10, loss = 1.08364781
# Iteration 11, loss = 1.07942636
# Iteration 12, loss = 1.07528299
# Iteration 13, loss = 1.07121404
# Iteration 14, loss = 1.06721548
# Iteration 15, loss = 1.06328292
# Iteration 16, loss = 1.05941173
# Iteration 17, loss = 1.05559717
# Iteration 18, loss = 1.05183438
# Iteration 19, loss = 1.04811857
# Iteration 20, loss = 1.04444503
# Iteration 21, loss = 1.04080917
# Iteration 22, loss = 1.03720661
# Iteration 23, loss = 1.03363319
# Iteration 24, loss = 1.03008500
# Iteration 25, loss = 1.02655837
# Iteration 26, loss = 1.02304991
# Iteration 27, loss = 1.01955643
# Iteration 28, loss = 1.01607498
# Iteration 29, loss = 1.01260280
# Iteration 30, loss = 1.00913731
# Iteration 31, loss = 1.00567612
# Iteration 32, loss = 1.00221698
# Iteration 33, loss = 0.99875776
# Iteration 34, loss = 0.99529651
# Iteration 35, loss = 0.99183138
# Iteration 36, loss = 0.98836066
# Iteration 37, loss = 0.98488278
# Iteration 38, loss = 0.98139628
# Iteration 39, loss = 0.97789984
# Iteration 40, loss = 0.97439226
# Iteration 41, loss = 0.97087244
# Iteration 42, loss = 0.96733941
# Iteration 43, loss = 0.96379229
# Iteration 44, loss = 0.96023028
# Iteration 45, loss = 0.95665267
# Iteration 46, loss = 0.95305885
# Iteration 47, loss = 0.94944825
# Iteration 48, loss = 0.94582038
# Iteration 49, loss = 0.94217479
# Iteration 50, loss = 0.93851112
# Iteration 51, loss = 0.93482901
# Iteration 52, loss = 0.93112819
# Iteration 53, loss = 0.92740839
# Iteration 54, loss = 0.92366942
# Iteration 55, loss = 0.91991109
# Iteration 56, loss = 0.91613327
# Iteration 57, loss = 0.91233587
# Iteration 58, loss = 0.90851880
# Iteration 59, loss = 0.90468203
# Iteration 60, loss = 0.90082555
# Iteration 61, loss = 0.89694940
# Iteration 62, loss = 0.89305363
# Iteration 63, loss = 0.88913833
# Iteration 64, loss = 0.88520362
# Iteration 65, loss = 0.88124966
# Iteration 66, loss = 0.87727662
# Iteration 67, loss = 0.87328472
# Iteration 68, loss = 0.86927420
# Iteration 69, loss = 0.86524533
# Iteration 70, loss = 0.86119843
# Iteration 71, loss = 0.85713381
# Iteration 72, loss = 0.85305184
# Iteration 73, loss = 0.84895290
# Iteration 74, loss = 0.84483740
# Iteration 75, loss = 0.84070579
# Iteration 76, loss = 0.83655853
# Iteration 77, loss = 0.83239609
# Iteration 78, loss = 0.82821900
# Iteration 79, loss = 0.82402778
# Iteration 80, loss = 0.81982299
# Iteration 81, loss = 0.81560519
# Iteration 82, loss = 0.81137497
# Iteration 83, loss = 0.80713295
# Iteration 84, loss = 0.80287974
# Iteration 85, loss = 0.79861598
# Iteration 86, loss = 0.79434233
# Iteration 87, loss = 0.79005944
# Iteration 88, loss = 0.78576799
# Iteration 89, loss = 0.78146868
# Iteration 90, loss = 0.77716219
# Iteration 91, loss = 0.77284923
# Iteration 92, loss = 0.76853051
# Iteration 93, loss = 0.76420674
# Iteration 94, loss = 0.75987865
# Iteration 95, loss = 0.75554697
# Iteration 96, loss = 0.75121242
# Iteration 97, loss = 0.74687574
# Iteration 98, loss = 0.74253765
# Iteration 99, loss = 0.73819889
# Iteration 100, loss = 0.73386019
# Iteration 101, loss = 0.72952227
# Iteration 102, loss = 0.72518587
# Iteration 103, loss = 0.72085170
# Iteration 104, loss = 0.71652049
# Iteration 105, loss = 0.71219295
# Iteration 106, loss = 0.70786978
# Iteration 107, loss = 0.70355169
# Iteration 108, loss = 0.69923936
# Iteration 109, loss = 0.69493348
# Iteration 110, loss = 0.69063473
# Iteration 111, loss = 0.68634377
# Iteration 112, loss = 0.68206127
# Iteration 113, loss = 0.67778785
# Iteration 114, loss = 0.67352416
# Iteration 115, loss = 0.66927083
# Iteration 116, loss = 0.66502845
# Iteration 117, loss = 0.66079763
# Iteration 118, loss = 0.65657894
# Iteration 119, loss = 0.65237297
# Iteration 120, loss = 0.64818027
# Iteration 121, loss = 0.64400137
# Iteration 122, loss = 0.63983681
# Iteration 123, loss = 0.63568710
# Iteration 124, loss = 0.63155274
# Iteration 125, loss = 0.62743421
# Iteration 126, loss = 0.62333198
# Iteration 127, loss = 0.61924650
# Iteration 128, loss = 0.61517821
# Iteration 129, loss = 0.61112752
# Iteration 130, loss = 0.60709485
# Iteration 131, loss = 0.60308058
# Iteration 132, loss = 0.59908509
# Iteration 133, loss = 0.59510873
# Iteration 134, loss = 0.59115185
# Iteration 135, loss = 0.58721477
# Iteration 136, loss = 0.58329781
# Iteration 137, loss = 0.57940126
# Iteration 138, loss = 0.57552540
# Iteration 139, loss = 0.57167050
# Iteration 140, loss = 0.56783681
# Iteration 141, loss = 0.56402456
# Iteration 142, loss = 0.56023399
# Iteration 143, loss = 0.55646529
# Iteration 144, loss = 0.55271865
# Iteration 145, loss = 0.54899428
# Iteration 146, loss = 0.54529231
# Iteration 147, loss = 0.54161292
# Iteration 148, loss = 0.53795625
# Iteration 149, loss = 0.53432241
# Iteration 150, loss = 0.53071153
# Iteration 151, loss = 0.52712371
# Iteration 152, loss = 0.52355905
# Iteration 153, loss = 0.52001762
# Iteration 154, loss = 0.51649950
# Iteration 155, loss = 0.51300474
# Iteration 156, loss = 0.50953340
# Iteration 157, loss = 0.50608552
# Iteration 158, loss = 0.50266112
# Iteration 159, loss = 0.49926023
# Iteration 160, loss = 0.49588285
# Iteration 161, loss = 0.49252900
# Iteration 162, loss = 0.48919865
# Iteration 163, loss = 0.48589181
# Iteration 164, loss = 0.48260845
# Iteration 165, loss = 0.47934855
# Iteration 166, loss = 0.47611205
# Iteration 167, loss = 0.47289893
# Iteration 168, loss = 0.46970914
# Iteration 169, loss = 0.46654261
# Iteration 170, loss = 0.46339930
# Iteration 171, loss = 0.46027912
# Iteration 172, loss = 0.45718201
# Iteration 173, loss = 0.45410790
# Iteration 174, loss = 0.45105669
# Iteration 175, loss = 0.44802831
# Iteration 176, loss = 0.44502266
# Iteration 177, loss = 0.44203965
# Iteration 178, loss = 0.43907918
# Iteration 179, loss = 0.43614115
# Iteration 180, loss = 0.43322544
# Iteration 181, loss = 0.43033196
# Iteration 182, loss = 0.42746059
# Iteration 183, loss = 0.42461121
# Iteration 184, loss = 0.42178372
# Iteration 185, loss = 0.41897798
# Iteration 186, loss = 0.41619387
# Iteration 187, loss = 0.41343128
# Iteration 188, loss = 0.41069008
# Iteration 189, loss = 0.40797014
# Iteration 190, loss = 0.40527132
# Iteration 191, loss = 0.40259351
# Iteration 192, loss = 0.39993656
# Iteration 193, loss = 0.39730035
# Iteration 194, loss = 0.39468474
# Iteration 195, loss = 0.39208959
# Iteration 196, loss = 0.38951477
# Iteration 197, loss = 0.38696015
# Iteration 198, loss = 0.38442558
# Iteration 199, loss = 0.38191093
# Iteration 200, loss = 0.37941606
# Iteration 201, loss = 0.37694084
# Iteration 202, loss = 0.37448512
# Iteration 203, loss = 0.37204876
# Iteration 204, loss = 0.36963163
# Iteration 205, loss = 0.36723359
# Iteration 206, loss = 0.36485449
# Iteration 207, loss = 0.36249421
# Iteration 208, loss = 0.36015260
# Iteration 209, loss = 0.35782952
# Iteration 210, loss = 0.35552484
# Iteration 211, loss = 0.35323841
# Iteration 212, loss = 0.35097011
# Iteration 213, loss = 0.34871979
# Iteration 214, loss = 0.34648733
# Iteration 215, loss = 0.34427257
# Iteration 216, loss = 0.34207539
# Iteration 217, loss = 0.33989565
# Iteration 218, loss = 0.33773322
# Iteration 219, loss = 0.33558796
# Iteration 220, loss = 0.33345975
# Iteration 221, loss = 0.33134844
# Iteration 222, loss = 0.32925392
# Iteration 223, loss = 0.32717603
# Iteration 224, loss = 0.32511467
# Iteration 225, loss = 0.32306969
# Iteration 226, loss = 0.32104097
# Iteration 227, loss = 0.31902838
# Iteration 228, loss = 0.31703179
# Iteration 229, loss = 0.31505107
# Iteration 230, loss = 0.31308611
# Iteration 231, loss = 0.31113677
# Iteration 232, loss = 0.30920293
# Iteration 233, loss = 0.30728446
# Iteration 234, loss = 0.30538125
# Iteration 235, loss = 0.30349318
# Iteration 236, loss = 0.30162011
# Iteration 237, loss = 0.29976193
# Iteration 238, loss = 0.29791853
# Iteration 239, loss = 0.29608977
# Iteration 240, loss = 0.29427555
# Iteration 241, loss = 0.29247575
# Iteration 242, loss = 0.29069024
# Iteration 243, loss = 0.28891892
# Iteration 244, loss = 0.28716167
# Iteration 245, loss = 0.28541837
# Iteration 246, loss = 0.28368892
# Iteration 247, loss = 0.28197319
# Iteration 248, loss = 0.28027108
# Iteration 249, loss = 0.27858248
# Iteration 250, loss = 0.27690728
# Iteration 251, loss = 0.27524536
# Iteration 252, loss = 0.27359662
# Iteration 253, loss = 0.27196094
# Iteration 254, loss = 0.27033823
# Iteration 255, loss = 0.26872838
# Iteration 256, loss = 0.26713128
# Iteration 257, loss = 0.26554682
# Iteration 258, loss = 0.26397490
# Iteration 259, loss = 0.26241542
# Iteration 260, loss = 0.26086828
# Iteration 261, loss = 0.25933337
# Iteration 262, loss = 0.25781058
# Iteration 263, loss = 0.25629983
# Iteration 264, loss = 0.25480102
# Iteration 265, loss = 0.25331403
# Iteration 266, loss = 0.25183877
# Iteration 267, loss = 0.25037515
# Iteration 268, loss = 0.24892307
# Iteration 269, loss = 0.24748243
# Iteration 270, loss = 0.24605314
# Iteration 271, loss = 0.24463510
# Iteration 272, loss = 0.24322821
# Iteration 273, loss = 0.24183239
# Iteration 274, loss = 0.24044754
# Iteration 275, loss = 0.23907356
# Iteration 276, loss = 0.23771037
# Iteration 277, loss = 0.23635788
# Iteration 278, loss = 0.23501599
# Iteration 279, loss = 0.23368462
# Iteration 280, loss = 0.23236367
# Iteration 281, loss = 0.23105307
# Iteration 282, loss = 0.22975271
# Iteration 283, loss = 0.22846251
# Iteration 284, loss = 0.22718239
# Iteration 285, loss = 0.22591227
# Iteration 286, loss = 0.22465205
# Iteration 287, loss = 0.22340165
# Iteration 288, loss = 0.22216099
# Iteration 289, loss = 0.22092998
# Iteration 290, loss = 0.21970854
# Iteration 291, loss = 0.21849660
# Iteration 292, loss = 0.21729406
# Iteration 293, loss = 0.21610085
# Iteration 294, loss = 0.21491689
# Iteration 295, loss = 0.21374210
# Iteration 296, loss = 0.21257639
# Iteration 297, loss = 0.21141970
# Iteration 298, loss = 0.21027194
# Iteration 299, loss = 0.20913303
# Iteration 300, loss = 0.20800291
# Iteration 301, loss = 0.20688149
# Iteration 302, loss = 0.20576869
# Iteration 303, loss = 0.20466445
# Iteration 304, loss = 0.20356869
# Iteration 305, loss = 0.20248133
# Iteration 306, loss = 0.20140231
# Iteration 307, loss = 0.20033154
# Iteration 308, loss = 0.19926897
# Iteration 309, loss = 0.19821451
# Iteration 310, loss = 0.19716809
# Iteration 311, loss = 0.19612966
# Iteration 312, loss = 0.19509912
# Iteration 313, loss = 0.19407643
# Iteration 314, loss = 0.19306150
# Iteration 315, loss = 0.19205428
# Iteration 316, loss = 0.19105468
# Iteration 317, loss = 0.19006266
# Iteration 318, loss = 0.18907813
# Iteration 319, loss = 0.18810104
# Iteration 320, loss = 0.18713131
# Iteration 321, loss = 0.18616889
# Iteration 322, loss = 0.18521371
# Iteration 323, loss = 0.18426571
# Iteration 324, loss = 0.18332482
# Iteration 325, loss = 0.18239098
# Iteration 326, loss = 0.18146413
# Iteration 327, loss = 0.18054420
# Iteration 328, loss = 0.17963114
# Iteration 329, loss = 0.17872489
# Iteration 330, loss = 0.17782538
# Iteration 331, loss = 0.17693256
# Iteration 332, loss = 0.17604636
# Iteration 333, loss = 0.17516674
# Iteration 334, loss = 0.17429362
# Iteration 335, loss = 0.17342696
# Iteration 336, loss = 0.17256669
# Iteration 337, loss = 0.17171276
# Iteration 338, loss = 0.17086511
# Iteration 339, loss = 0.17002369
# Iteration 340, loss = 0.16918845
# Iteration 341, loss = 0.16835932
# Iteration 342, loss = 0.16753626
# Iteration 343, loss = 0.16671920
# Iteration 344, loss = 0.16590811
# Iteration 345, loss = 0.16510292
# Iteration 346, loss = 0.16430358
# Iteration 347, loss = 0.16351004
# Iteration 348, loss = 0.16272225
# Iteration 349, loss = 0.16194016
# Iteration 350, loss = 0.16116372
# Iteration 351, loss = 0.16039287
# Iteration 352, loss = 0.15962758
# Iteration 353, loss = 0.15886778
# Iteration 354, loss = 0.15811344
# Iteration 355, loss = 0.15736449
# Iteration 356, loss = 0.15662091
# Iteration 357, loss = 0.15588263
# Iteration 358, loss = 0.15514961
# Iteration 359, loss = 0.15442180
# Iteration 360, loss = 0.15369917
# Iteration 361, loss = 0.15298165
# Iteration 362, loss = 0.15226922
# Iteration 363, loss = 0.15156182
# Iteration 364, loss = 0.15085940
# Iteration 365, loss = 0.15016193
# Iteration 366, loss = 0.14946937
# Iteration 367, loss = 0.14878166
# Iteration 368, loss = 0.14809876
# Iteration 369, loss = 0.14742064
# Iteration 370, loss = 0.14674725
# Iteration 371, loss = 0.14607855
# Iteration 372, loss = 0.14541450
# Iteration 373, loss = 0.14475505
# Iteration 374, loss = 0.14410017
# Iteration 375, loss = 0.14344982
# Iteration 376, loss = 0.14280396
# Iteration 377, loss = 0.14216255
# Iteration 378, loss = 0.14152554
# Iteration 379, loss = 0.14089291
# Iteration 380, loss = 0.14026460
# Iteration 381, loss = 0.13964060
# Iteration 382, loss = 0.13902085
# Iteration 383, loss = 0.13840532
# Iteration 384, loss = 0.13779397
# Iteration 385, loss = 0.13718677
# Iteration 386, loss = 0.13658369
# Iteration 387, loss = 0.13598468
# Iteration 388, loss = 0.13538970
# Iteration 389, loss = 0.13479874
# Iteration 390, loss = 0.13421174
# Iteration 391, loss = 0.13362868
# Iteration 392, loss = 0.13304952
# Iteration 393, loss = 0.13247423
# Iteration 394, loss = 0.13190278
# Iteration 395, loss = 0.13133513
# Iteration 396, loss = 0.13077124
# Iteration 397, loss = 0.13021109
# Iteration 398, loss = 0.12965465
# Iteration 399, loss = 0.12910188
# Iteration 400, loss = 0.12855275
# Iteration 401, loss = 0.12800724
# Iteration 402, loss = 0.12746530
# Iteration 403, loss = 0.12692691
# Iteration 404, loss = 0.12639203
# Iteration 405, loss = 0.12586065
# Iteration 406, loss = 0.12533272
# Iteration 407, loss = 0.12480823
# Iteration 408, loss = 0.12428713
# Iteration 409, loss = 0.12376940
# Iteration 410, loss = 0.12325502
# Iteration 411, loss = 0.12274395
# Iteration 412, loss = 0.12223617
# Iteration 413, loss = 0.12173164
# Iteration 414, loss = 0.12123035
# Iteration 415, loss = 0.12073226
# Iteration 416, loss = 0.12023735
# Iteration 417, loss = 0.11974558
# Iteration 418, loss = 0.11925694
# Iteration 419, loss = 0.11877140
# Iteration 420, loss = 0.11828893
# Iteration 421, loss = 0.11780950
# Iteration 422, loss = 0.11733309
# Iteration 423, loss = 0.11685968
# Iteration 424, loss = 0.11638924
# Iteration 425, loss = 0.11592175
# Iteration 426, loss = 0.11545717
# Iteration 427, loss = 0.11499549
# Iteration 428, loss = 0.11453668
# Iteration 429, loss = 0.11408073
# Iteration 430, loss = 0.11362759
# Iteration 431, loss = 0.11317726
# Iteration 432, loss = 0.11272971
# Iteration 433, loss = 0.11228492
# Iteration 434, loss = 0.11184285
# Iteration 435, loss = 0.11140350
# Iteration 436, loss = 0.11096684
# Iteration 437, loss = 0.11053284
# Iteration 438, loss = 0.11010149
# Iteration 439, loss = 0.10967276
# Iteration 440, loss = 0.10924663
# Iteration 441, loss = 0.10882309
# Iteration 442, loss = 0.10840210
# Iteration 443, loss = 0.10798365
# Iteration 444, loss = 0.10756772
# Iteration 445, loss = 0.10715429
# Iteration 446, loss = 0.10674334
# Iteration 447, loss = 0.10633484
# Iteration 448, loss = 0.10592879
# Iteration 449, loss = 0.10552515
# Iteration 450, loss = 0.10512391
# Iteration 451, loss = 0.10472505
# Iteration 452, loss = 0.10432855
# Iteration 453, loss = 0.10393439
# Iteration 454, loss = 0.10354256
# Iteration 455, loss = 0.10315303
# Iteration 456, loss = 0.10276579
# Iteration 457, loss = 0.10238081
# Iteration 458, loss = 0.10199809
# Iteration 459, loss = 0.10161760
# Iteration 460, loss = 0.10123932
# Iteration 461, loss = 0.10086324
# Iteration 462, loss = 0.10048934
# Iteration 463, loss = 0.10011761
# Iteration 464, loss = 0.09974802
# Iteration 465, loss = 0.09938055
# Iteration 466, loss = 0.09901521
# Iteration 467, loss = 0.09865195
# Iteration 468, loss = 0.09829078
# Iteration 469, loss = 0.09793167
# Iteration 470, loss = 0.09757461
# Iteration 471, loss = 0.09721958
# Iteration 472, loss = 0.09686657
# Iteration 473, loss = 0.09651556
# Iteration 474, loss = 0.09616653
# Iteration 475, loss = 0.09581947
# Iteration 476, loss = 0.09547436
# Iteration 477, loss = 0.09513120
# Iteration 478, loss = 0.09478996
# Iteration 479, loss = 0.09445063
# Iteration 480, loss = 0.09411319
# Iteration 481, loss = 0.09377764
# Iteration 482, loss = 0.09344395
# Iteration 483, loss = 0.09311211
# Iteration 484, loss = 0.09278212
# Iteration 485, loss = 0.09245394
# Iteration 486, loss = 0.09212758
# Iteration 487, loss = 0.09180301
# Iteration 488, loss = 0.09148023
# Iteration 489, loss = 0.09115922
# Iteration 490, loss = 0.09083996
# Iteration 491, loss = 0.09052245
# Iteration 492, loss = 0.09020667
# Iteration 493, loss = 0.08989260
# Iteration 494, loss = 0.08958024
# Iteration 495, loss = 0.08926957
# Iteration 496, loss = 0.08896058
# Iteration 497, loss = 0.08865326
# Iteration 498, loss = 0.08834759
# Iteration 499, loss = 0.08804357
# Iteration 500, loss = 0.08774117
# Iteration 501, loss = 0.08744040
# Iteration 502, loss = 0.08714123
# Iteration 503, loss = 0.08684365
# Iteration 504, loss = 0.08654766
# Iteration 505, loss = 0.08625324
# Iteration 506, loss = 0.08596037
# Iteration 507, loss = 0.08566906
# Iteration 508, loss = 0.08537928
# Iteration 509, loss = 0.08509103
# Iteration 510, loss = 0.08480430
# Iteration 511, loss = 0.08451907
# Iteration 512, loss = 0.08423533
# Iteration 513, loss = 0.08395307
# Iteration 514, loss = 0.08367229
# Iteration 515, loss = 0.08339297
# Iteration 516, loss = 0.08311509
# Iteration 517, loss = 0.08283866
# Iteration 518, loss = 0.08256366
# Iteration 519, loss = 0.08229008
# Iteration 520, loss = 0.08201790
# Iteration 521, loss = 0.08174713
# Iteration 522, loss = 0.08147775
# Iteration 523, loss = 0.08120974
# Iteration 524, loss = 0.08094311
# Iteration 525, loss = 0.08067784
# Iteration 526, loss = 0.08041391
# Iteration 527, loss = 0.08015133
# Iteration 528, loss = 0.07989008
# Iteration 529, loss = 0.07963016
# Iteration 530, loss = 0.07937154
# Iteration 531, loss = 0.07911423
# Iteration 532, loss = 0.07885822
# Iteration 533, loss = 0.07860349
# Iteration 534, loss = 0.07835004
# Iteration 535, loss = 0.07809786
# Iteration 536, loss = 0.07784694
# Iteration 537, loss = 0.07759726
# Iteration 538, loss = 0.07734883
# Iteration 539, loss = 0.07710164
# Iteration 540, loss = 0.07685567
# Iteration 541, loss = 0.07661091
# Iteration 542, loss = 0.07636737
# Iteration 543, loss = 0.07612502
# Iteration 544, loss = 0.07588387
# Iteration 545, loss = 0.07564390
# Iteration 546, loss = 0.07540510
# Iteration 547, loss = 0.07516748
# Iteration 548, loss = 0.07493101
# Iteration 549, loss = 0.07469570
# Iteration 550, loss = 0.07446153
# Iteration 551, loss = 0.07422850
# Iteration 552, loss = 0.07399659
# Iteration 553, loss = 0.07376581
# Iteration 554, loss = 0.07353614
# Iteration 555, loss = 0.07330758
# Iteration 556, loss = 0.07308012
# Iteration 557, loss = 0.07285374
# Iteration 558, loss = 0.07262846
# Iteration 559, loss = 0.07240425
# Iteration 560, loss = 0.07218111
# Iteration 561, loss = 0.07195903
# Iteration 562, loss = 0.07173801
# Iteration 563, loss = 0.07151804
# Iteration 564, loss = 0.07129911
# Iteration 565, loss = 0.07108122
# Iteration 566, loss = 0.07086436
# Iteration 567, loss = 0.07064851
# Iteration 568, loss = 0.07043368
# Iteration 569, loss = 0.07021987
# Iteration 570, loss = 0.07000705
# Iteration 571, loss = 0.06979523
# Iteration 572, loss = 0.06958439
# Iteration 573, loss = 0.06937454
# Iteration 574, loss = 0.06916567
# Iteration 575, loss = 0.06895777
# Iteration 576, loss = 0.06875083
# Iteration 577, loss = 0.06854484
# Iteration 578, loss = 0.06833981
# Iteration 579, loss = 0.06813573
# Iteration 580, loss = 0.06793258
# Iteration 581, loss = 0.06773037
# Iteration 582, loss = 0.06752908
# Iteration 583, loss = 0.06732871
# Iteration 584, loss = 0.06712927
# Iteration 585, loss = 0.06693073
# Iteration 586, loss = 0.06673309
# Iteration 587, loss = 0.06653635
# Iteration 588, loss = 0.06634051
# Iteration 589, loss = 0.06614555
# Iteration 590, loss = 0.06595148
# Iteration 591, loss = 0.06575828
# Iteration 592, loss = 0.06556595
# Iteration 593, loss = 0.06537448
# Iteration 594, loss = 0.06518388
# Iteration 595, loss = 0.06499413
# Iteration 596, loss = 0.06480522
# Iteration 597, loss = 0.06461717
# Iteration 598, loss = 0.06442995
# Iteration 599, loss = 0.06424356
# Iteration 600, loss = 0.06405800
# Iteration 601, loss = 0.06387327
# Iteration 602, loss = 0.06368935
# Iteration 603, loss = 0.06350624
# Iteration 604, loss = 0.06332395
# Iteration 605, loss = 0.06314245
# Iteration 606, loss = 0.06296176
# Iteration 607, loss = 0.06278186
# Iteration 608, loss = 0.06260274
# Iteration 609, loss = 0.06242441
# Iteration 610, loss = 0.06224686
# Iteration 611, loss = 0.06207009
# Iteration 612, loss = 0.06189408
# Iteration 613, loss = 0.06171883
# Iteration 614, loss = 0.06154435
# Iteration 615, loss = 0.06137063
# Iteration 616, loss = 0.06119765
# Iteration 617, loss = 0.06102542
# Iteration 618, loss = 0.06085393
# Iteration 619, loss = 0.06068318
# Iteration 620, loss = 0.06051317
# Iteration 621, loss = 0.06034388
# Iteration 622, loss = 0.06017532
# Iteration 623, loss = 0.06000748
# Iteration 624, loss = 0.05984035
# Iteration 625, loss = 0.05967393
# Iteration 626, loss = 0.05950823
# Iteration 627, loss = 0.05934322
# Iteration 628, loss = 0.05917892
# Iteration 629, loss = 0.05901531
# Iteration 630, loss = 0.05885239
# Iteration 631, loss = 0.05869016
# Iteration 632, loss = 0.05852862
# Iteration 633, loss = 0.05836775
# Iteration 634, loss = 0.05820755
# Iteration 635, loss = 0.05804803
# Iteration 636, loss = 0.05788918
# Iteration 637, loss = 0.05773098
# Iteration 638, loss = 0.05757345
# Iteration 639, loss = 0.05741658
# Iteration 640, loss = 0.05726035
# Iteration 641, loss = 0.05710478
# Iteration 642, loss = 0.05694984
# Iteration 643, loss = 0.05679555
# Iteration 644, loss = 0.05664190
# Iteration 645, loss = 0.05648888
# Iteration 646, loss = 0.05633649
# Iteration 647, loss = 0.05618473
# Iteration 648, loss = 0.05603359
# Iteration 649, loss = 0.05588306
# Iteration 650, loss = 0.05573316
# Iteration 651, loss = 0.05558386
# Iteration 652, loss = 0.05543518
# Iteration 653, loss = 0.05528710
# Iteration 654, loss = 0.05513962
# Iteration 655, loss = 0.05499274
# Iteration 656, loss = 0.05484646
# Iteration 657, loss = 0.05470077
# Iteration 658, loss = 0.05455566
# Iteration 659, loss = 0.05441114
# Iteration 660, loss = 0.05426721
# Iteration 661, loss = 0.05412385
# Iteration 662, loss = 0.05398107
# Iteration 663, loss = 0.05383886
# Iteration 664, loss = 0.05369721
# Iteration 665, loss = 0.05355614
# Iteration 666, loss = 0.05341563
# Iteration 667, loss = 0.05327567
# Iteration 668, loss = 0.05313628
# Iteration 669, loss = 0.05299744
# Iteration 670, loss = 0.05285914
# Iteration 671, loss = 0.05272140
# Iteration 672, loss = 0.05258420
# Iteration 673, loss = 0.05244754
# Iteration 674, loss = 0.05231142
# Iteration 675, loss = 0.05217584
# Iteration 676, loss = 0.05204079
# Iteration 677, loss = 0.05190627
# Iteration 678, loss = 0.05177227
# Iteration 679, loss = 0.05163880
# Iteration 680, loss = 0.05150585
# Iteration 681, loss = 0.05137342
# Iteration 682, loss = 0.05124151
# Iteration 683, loss = 0.05111011
# Iteration 684, loss = 0.05097922
# Iteration 685, loss = 0.05084883
# Iteration 686, loss = 0.05071895
# Iteration 687, loss = 0.05058958
# Iteration 688, loss = 0.05046070
# Iteration 689, loss = 0.05033232
# Iteration 690, loss = 0.05020443
# Iteration 691, loss = 0.05007703
# Iteration 692, loss = 0.04995013
# Iteration 693, loss = 0.04982371
# Iteration 694, loss = 0.04969777
# Iteration 695, loss = 0.04957231
# Iteration 696, loss = 0.04944734
# Iteration 697, loss = 0.04932283
# Iteration 698, loss = 0.04919881
# Iteration 699, loss = 0.04907525
# Iteration 700, loss = 0.04895216
# Iteration 701, loss = 0.04882954
# Iteration 702, loss = 0.04870738
# Iteration 703, loss = 0.04858568
# Iteration 704, loss = 0.04846445
# Iteration 705, loss = 0.04834366
# Iteration 706, loss = 0.04822334
# Iteration 707, loss = 0.04810346
# Iteration 708, loss = 0.04798404
# Iteration 709, loss = 0.04786506
# Iteration 710, loss = 0.04774652
# Iteration 711, loss = 0.04762843
# Iteration 712, loss = 0.04751078
# Iteration 713, loss = 0.04739356
# Iteration 714, loss = 0.04727679
# Iteration 715, loss = 0.04716044
# Iteration 716, loss = 0.04704453
# Iteration 717, loss = 0.04692905
# Iteration 718, loss = 0.04681399
# Iteration 719, loss = 0.04669936
# Iteration 720, loss = 0.04658515
# Iteration 721, loss = 0.04647136
# Iteration 722, loss = 0.04635799
# Iteration 723, loss = 0.04624503
# Iteration 724, loss = 0.04613249
# Iteration 725, loss = 0.04602036
# Iteration 726, loss = 0.04590864
# Iteration 727, loss = 0.04579733
# Iteration 728, loss = 0.04568642
# Iteration 729, loss = 0.04557592
# Iteration 730, loss = 0.04546582
# Iteration 731, loss = 0.04535612
# Iteration 732, loss = 0.04524682
# Iteration 733, loss = 0.04513791
# Iteration 734, loss = 0.04502940
# Iteration 735, loss = 0.04492128
# Iteration 736, loss = 0.04481355
# Iteration 737, loss = 0.04470620
# Iteration 738, loss = 0.04459924
# Iteration 739, loss = 0.04449267
# Iteration 740, loss = 0.04438648
# Iteration 741, loss = 0.04428067
# Iteration 742, loss = 0.04417524
# Iteration 743, loss = 0.04407018
# Iteration 744, loss = 0.04396550
# Iteration 745, loss = 0.04386119
# Iteration 746, loss = 0.04375725
# Iteration 747, loss = 0.04365368
# Iteration 748, loss = 0.04355048
# Iteration 749, loss = 0.04344765
# Iteration 750, loss = 0.04334518
# Iteration 751, loss = 0.04324307
# Iteration 752, loss = 0.04314132
# Iteration 753, loss = 0.04303993
# Iteration 754, loss = 0.04293890
# Iteration 755, loss = 0.04283822
# Iteration 756, loss = 0.04273789
# Iteration 757, loss = 0.04263792
# Iteration 758, loss = 0.04253830
# Iteration 759, loss = 0.04243902
# Iteration 760, loss = 0.04234009
# Iteration 761, loss = 0.04224151
# Iteration 762, loss = 0.04214327
# Iteration 763, loss = 0.04204537
# Iteration 764, loss = 0.04194782
# Iteration 765, loss = 0.04185060
# Iteration 766, loss = 0.04175371
# Iteration 767, loss = 0.04165717
# Iteration 768, loss = 0.04156095
# Iteration 769, loss = 0.04146507
# Iteration 770, loss = 0.04136952
# Iteration 771, loss = 0.04127430
# Iteration 772, loss = 0.04117940
# Iteration 773, loss = 0.04108483
# Iteration 774, loss = 0.04099059
# Iteration 775, loss = 0.04089667
# Iteration 776, loss = 0.04080306
# Iteration 777, loss = 0.04070978
# Iteration 778, loss = 0.04061682
# Iteration 779, loss = 0.04052418
# Iteration 780, loss = 0.04043184
# Iteration 781, loss = 0.04033983
# Iteration 782, loss = 0.04024812
# Iteration 783, loss = 0.04015673
# Iteration 784, loss = 0.04006564
# Iteration 785, loss = 0.03997487
# Iteration 786, loss = 0.03988440
# Iteration 787, loss = 0.03979423
# Iteration 788, loss = 0.03970437
# Iteration 789, loss = 0.03961481
# Iteration 790, loss = 0.03952556
# Iteration 791, loss = 0.03943660
# Iteration 792, loss = 0.03934794
# Iteration 793, loss = 0.03925958
# Iteration 794, loss = 0.03917151
# Iteration 795, loss = 0.03908374
# Iteration 796, loss = 0.03899626
# Iteration 797, loss = 0.03890907
# Iteration 798, loss = 0.03882217
# Iteration 799, loss = 0.03873556
# Iteration 800, loss = 0.03864923
# Iteration 801, loss = 0.03856320
# Iteration 802, loss = 0.03847745
# Iteration 803, loss = 0.03839198
# Iteration 804, loss = 0.03830679
# Iteration 805, loss = 0.03822189
# Iteration 806, loss = 0.03813726
# Iteration 807, loss = 0.03805291
# Iteration 808, loss = 0.03796884
# Iteration 809, loss = 0.03788505
# Iteration 810, loss = 0.03780153
# Iteration 811, loss = 0.03771829
# Iteration 812, loss = 0.03763531
# Iteration 813, loss = 0.03755261
# Iteration 814, loss = 0.03747018
# Iteration 815, loss = 0.03738802
# Iteration 816, loss = 0.03730612
# Iteration 817, loss = 0.03722449
# Iteration 818, loss = 0.03714313
# Iteration 819, loss = 0.03706202
# Iteration 820, loss = 0.03698119
# Iteration 821, loss = 0.03690061
# Iteration 822, loss = 0.03682029
# Iteration 823, loss = 0.03674024
# Iteration 824, loss = 0.03666044
# Iteration 825, loss = 0.03658090
# Iteration 826, loss = 0.03650161
# Iteration 827, loss = 0.03642258
# Iteration 828, loss = 0.03634380
# Iteration 829, loss = 0.03626527
# Iteration 830, loss = 0.03618700
# Iteration 831, loss = 0.03610898
# Iteration 832, loss = 0.03603120
# Iteration 833, loss = 0.03595368
# Iteration 834, loss = 0.03587640
# Iteration 835, loss = 0.03579936
# Iteration 836, loss = 0.03572257
# Iteration 837, loss = 0.03564603
# Iteration 838, loss = 0.03556973
# Iteration 839, loss = 0.03549367
# Iteration 840, loss = 0.03541785
# Iteration 841, loss = 0.03534227
# Iteration 842, loss = 0.03526693
# Iteration 843, loss = 0.03519182
# Iteration 844, loss = 0.03511695
# Iteration 845, loss = 0.03504232
# Iteration 846, loss = 0.03496793
# Iteration 847, loss = 0.03489376
# Iteration 848, loss = 0.03481983
# Iteration 849, loss = 0.03474613
# Iteration 850, loss = 0.03467266
# Iteration 851, loss = 0.03459942
# Iteration 852, loss = 0.03452641
# Iteration 853, loss = 0.03445363
# Iteration 854, loss = 0.03438107
# Iteration 855, loss = 0.03430874
# Iteration 856, loss = 0.03423663
# Iteration 857, loss = 0.03416475
# Iteration 858, loss = 0.03409309
# Iteration 859, loss = 0.03402165
# Iteration 860, loss = 0.03395043
# Iteration 861, loss = 0.03387943
# Iteration 862, loss = 0.03380865
# Iteration 863, loss = 0.03373809
# Iteration 864, loss = 0.03366775
# Iteration 865, loss = 0.03359762
# Iteration 866, loss = 0.03352771
# Iteration 867, loss = 0.03345801
# Iteration 868, loss = 0.03338853
# Iteration 869, loss = 0.03331926
# Iteration 870, loss = 0.03325020
# Iteration 871, loss = 0.03318135
# Iteration 872, loss = 0.03311271
# Iteration 873, loss = 0.03304429
# Iteration 874, loss = 0.03297606
# Iteration 875, loss = 0.03290805
# Iteration 876, loss = 0.03284024
# Iteration 877, loss = 0.03277264
# Iteration 878, loss = 0.03270525
# Iteration 879, loss = 0.03263806
# Iteration 880, loss = 0.03257107
# Iteration 881, loss = 0.03250428
# Iteration 882, loss = 0.03243770
# Iteration 883, loss = 0.03237131
# Iteration 884, loss = 0.03230513
# Iteration 885, loss = 0.03223914
# Iteration 886, loss = 0.03217336
# Iteration 887, loss = 0.03210777
# Iteration 888, loss = 0.03204237
# Iteration 889, loss = 0.03197718
# Iteration 890, loss = 0.03191217
# Iteration 891, loss = 0.03184736
# Iteration 892, loss = 0.03178275
# Iteration 893, loss = 0.03171833
# Iteration 894, loss = 0.03165410
# Iteration 895, loss = 0.03159006
# Iteration 896, loss = 0.03152621
# Iteration 897, loss = 0.03146255
# Iteration 898, loss = 0.03139908
# Iteration 899, loss = 0.03133580
# Iteration 900, loss = 0.03127270
# Iteration 901, loss = 0.03120980
# Iteration 902, loss = 0.03114707
# Iteration 903, loss = 0.03108453
# Iteration 904, loss = 0.03102218
# Iteration 905, loss = 0.03096001
# Iteration 906, loss = 0.03089802
# Iteration 907, loss = 0.03083622
# Iteration 908, loss = 0.03077459
# Iteration 909, loss = 0.03071315
# Iteration 910, loss = 0.03065189
# Iteration 911, loss = 0.03059080
# Iteration 912, loss = 0.03052990
# Iteration 913, loss = 0.03046917
# Iteration 914, loss = 0.03040862
# Iteration 915, loss = 0.03034824
# Iteration 916, loss = 0.03028805
# Iteration 917, loss = 0.03022802
# Iteration 918, loss = 0.03016817
# Iteration 919, loss = 0.03010850
# Iteration 920, loss = 0.03004899
# Iteration 921, loss = 0.02998966
# Iteration 922, loss = 0.02993050
# Iteration 923, loss = 0.02987151
# Iteration 924, loss = 0.02981269
# Iteration 925, loss = 0.02975404
# Iteration 926, loss = 0.02969556
# Iteration 927, loss = 0.02963725
# Iteration 928, loss = 0.02957911
# Iteration 929, loss = 0.02952113
# Iteration 930, loss = 0.02946332
# Iteration 931, loss = 0.02940567
# Iteration 932, loss = 0.02934819
# Iteration 933, loss = 0.02929088
# Iteration 934, loss = 0.02923372
# Iteration 935, loss = 0.02917673
# Iteration 936, loss = 0.02911991
# Iteration 937, loss = 0.02906324
# Iteration 938, loss = 0.02900673
# Iteration 939, loss = 0.02895039
# Iteration 940, loss = 0.02889421
# Iteration 941, loss = 0.02883818
# Iteration 942, loss = 0.02878232
# Iteration 943, loss = 0.02872661
# Iteration 944, loss = 0.02867106
# Iteration 945, loss = 0.02861566
# Iteration 946, loss = 0.02856042
# Iteration 947, loss = 0.02850534
# Iteration 948, loss = 0.02845042
# Iteration 949, loss = 0.02839564
# Iteration 950, loss = 0.02834102
# Iteration 951, loss = 0.02828656
# Iteration 952, loss = 0.02823225
# Iteration 953, loss = 0.02817809
# Iteration 954, loss = 0.02812408
# Iteration 955, loss = 0.02807022
# Iteration 956, loss = 0.02801651
# Iteration 957, loss = 0.02796295
# Iteration 958, loss = 0.02790954
# Iteration 959, loss = 0.02785628
# Iteration 960, loss = 0.02780317
# Iteration 961, loss = 0.02775021
# Iteration 962, loss = 0.02769739
# Iteration 963, loss = 0.02764472
# Iteration 964, loss = 0.02759220
# Iteration 965, loss = 0.02753982
# Iteration 966, loss = 0.02748758
# Iteration 967, loss = 0.02743549
# Iteration 968, loss = 0.02738355
# Iteration 969, loss = 0.02733174
# Iteration 970, loss = 0.02728008
# Iteration 971, loss = 0.02722856
# Iteration 972, loss = 0.02717719
# Iteration 973, loss = 0.02712595
# Iteration 974, loss = 0.02707485
# Iteration 975, loss = 0.02702390
# Iteration 976, loss = 0.02697308
# Iteration 977, loss = 0.02692241
# Iteration 978, loss = 0.02687187
# Iteration 979, loss = 0.02682147
# Iteration 980, loss = 0.02677120
# Iteration 981, loss = 0.02672108
# Iteration 982, loss = 0.02667109
# Iteration 983, loss = 0.02662123
# Iteration 984, loss = 0.02657152
# Iteration 985, loss = 0.02652193
# Iteration 986, loss = 0.02647248
# Iteration 987, loss = 0.02642317
# Iteration 988, loss = 0.02637399
# Iteration 989, loss = 0.02632494
# Iteration 990, loss = 0.02627602
# Iteration 991, loss = 0.02622724
# Iteration 992, loss = 0.02617859
# Iteration 993, loss = 0.02613006
# Iteration 994, loss = 0.02608167
# Iteration 995, loss = 0.02603341
# Iteration 996, loss = 0.02598528
# Iteration 997, loss = 0.02593728
# Iteration 998, loss = 0.02588941
# Iteration 999, loss = 0.02584166
# Iteration 1000, loss = 0.02579404
# Iteration 1001, loss = 0.02574655
# Iteration 1002, loss = 0.02569919
# Iteration 1003, loss = 0.02565195
# Iteration 1004, loss = 0.02560484
# Iteration 1005, loss = 0.02555785
# Iteration 1006, loss = 0.02551099
# Iteration 1007, loss = 0.02546426
# Iteration 1008, loss = 0.02541764
# Iteration 1009, loss = 0.02537116
# Iteration 1010, loss = 0.02532479
# Iteration 1011, loss = 0.02527855
# Iteration 1012, loss = 0.02523243
# Iteration 1013, loss = 0.02518643
# Iteration 1014, loss = 0.02514055
# Iteration 1015, loss = 0.02509480
# Iteration 1016, loss = 0.02504916
# Iteration 1017, loss = 0.02500365
# Iteration 1018, loss = 0.02495825
# Iteration 1019, loss = 0.02491297
# Iteration 1020, loss = 0.02486782
# Iteration 1021, loss = 0.02482278
# Iteration 1022, loss = 0.02477786
# Iteration 1023, loss = 0.02473305
# Iteration 1024, loss = 0.02468837
# Iteration 1025, loss = 0.02464380
# Iteration 1026, loss = 0.02459934
# Iteration 1027, loss = 0.02455501
# Iteration 1028, loss = 0.02451079
# Iteration 1029, loss = 0.02446668
# Iteration 1030, loss = 0.02442269
# Iteration 1031, loss = 0.02437881
# Iteration 1032, loss = 0.02433505
# Iteration 1033, loss = 0.02429140
# Iteration 1034, loss = 0.02424786
# Iteration 1035, loss = 0.02420444
# Iteration 1036, loss = 0.02416113
# Iteration 1037, loss = 0.02411793
# Iteration 1038, loss = 0.02407484
# Iteration 1039, loss = 0.02403186
# Iteration 1040, loss = 0.02398900
# Iteration 1041, loss = 0.02394624
# Iteration 1042, loss = 0.02390359
# Iteration 1043, loss = 0.02386106
# Iteration 1044, loss = 0.02381863
# Iteration 1045, loss = 0.02377631
# Iteration 1046, loss = 0.02373410
# Iteration 1047, loss = 0.02369200
# Iteration 1048, loss = 0.02365001
# Iteration 1049, loss = 0.02360812
# Iteration 1050, loss = 0.02356634
# Iteration 1051, loss = 0.02352467
# Iteration 1052, loss = 0.02348311
# Iteration 1053, loss = 0.02344165
# Iteration 1054, loss = 0.02340029
# Iteration 1055, loss = 0.02335904
# Iteration 1056, loss = 0.02331790
# Iteration 1057, loss = 0.02327686
# Iteration 1058, loss = 0.02323592
# Iteration 1059, loss = 0.02319509
# Iteration 1060, loss = 0.02315436
# Iteration 1061, loss = 0.02311373
# Iteration 1062, loss = 0.02307321
# Iteration 1063, loss = 0.02303279
# Iteration 1064, loss = 0.02299247
# Iteration 1065, loss = 0.02295225
# Iteration 1066, loss = 0.02291213
# Iteration 1067, loss = 0.02287212
# Iteration 1068, loss = 0.02283220
# Iteration 1069, loss = 0.02279239
# Iteration 1070, loss = 0.02275268
# Iteration 1071, loss = 0.02271306
# Iteration 1072, loss = 0.02267355
# Iteration 1073, loss = 0.02263413
# Iteration 1074, loss = 0.02259481
# Iteration 1075, loss = 0.02255559
# Iteration 1076, loss = 0.02251647
# Iteration 1077, loss = 0.02247744
# Iteration 1078, loss = 0.02243852
# Iteration 1079, loss = 0.02239969
# Iteration 1080, loss = 0.02236095
# Iteration 1081, loss = 0.02232232
# Iteration 1082, loss = 0.02228378
# Iteration 1083, loss = 0.02224533
# Iteration 1084, loss = 0.02220698
# Iteration 1085, loss = 0.02216872
# Iteration 1086, loss = 0.02213056
# Iteration 1087, loss = 0.02209250
# Iteration 1088, loss = 0.02205452
# Iteration 1089, loss = 0.02201665
# Iteration 1090, loss = 0.02197886
# Iteration 1091, loss = 0.02194117
# Iteration 1092, loss = 0.02190357
# Iteration 1093, loss = 0.02186606
# Iteration 1094, loss = 0.02182865
# Iteration 1095, loss = 0.02179133
# Iteration 1096, loss = 0.02175410
# Iteration 1097, loss = 0.02171696
# Iteration 1098, loss = 0.02167991
# Iteration 1099, loss = 0.02164295
# Iteration 1100, loss = 0.02160608
# Iteration 1101, loss = 0.02156930
# Iteration 1102, loss = 0.02153262
# Iteration 1103, loss = 0.02149602
# Iteration 1104, loss = 0.02145951
# Iteration 1105, loss = 0.02142309
# Iteration 1106, loss = 0.02138676
# Iteration 1107, loss = 0.02135051
# Iteration 1108, loss = 0.02131436
# Iteration 1109, loss = 0.02127829
# Iteration 1110, loss = 0.02124231
# Iteration 1111, loss = 0.02120642
# Iteration 1112, loss = 0.02117061
# Iteration 1113, loss = 0.02113489
# Iteration 1114, loss = 0.02109926
# Iteration 1115, loss = 0.02106371
# Iteration 1116, loss = 0.02102825
# Iteration 1117, loss = 0.02099288
# Iteration 1118, loss = 0.02095759
# Iteration 1119, loss = 0.02092238
# Iteration 1120, loss = 0.02088726
# Iteration 1121, loss = 0.02085222
# Iteration 1122, loss = 0.02081727
# Iteration 1123, loss = 0.02078240
# Iteration 1124, loss = 0.02074762
# Iteration 1125, loss = 0.02071292
# Iteration 1126, loss = 0.02067830
# Iteration 1127, loss = 0.02064376
# Iteration 1128, loss = 0.02060931
# Iteration 1129, loss = 0.02057494
# Iteration 1130, loss = 0.02054065
# Iteration 1131, loss = 0.02050644
# Iteration 1132, loss = 0.02047232
# Iteration 1133, loss = 0.02043827
# Iteration 1134, loss = 0.02040431
# Iteration 1135, loss = 0.02037042
# Iteration 1136, loss = 0.02033662
# Iteration 1137, loss = 0.02030290
# Iteration 1138, loss = 0.02026926
# Iteration 1139, loss = 0.02023569
# Iteration 1140, loss = 0.02020221
# Iteration 1141, loss = 0.02016881
# Iteration 1142, loss = 0.02013548
# Iteration 1143, loss = 0.02010223
# Iteration 1144, loss = 0.02006907
# Iteration 1145, loss = 0.02003598
# Iteration 1146, loss = 0.02000296
# Iteration 1147, loss = 0.01997003
# Iteration 1148, loss = 0.01993717
# Iteration 1149, loss = 0.01990439
# Iteration 1150, loss = 0.01987169
# Iteration 1151, loss = 0.01983906
# Iteration 1152, loss = 0.01980651
# Iteration 1153, loss = 0.01977404
# Iteration 1154, loss = 0.01974164
# Iteration 1155, loss = 0.01970932
# Iteration 1156, loss = 0.01967707
# Iteration 1157, loss = 0.01964490
# Iteration 1158, loss = 0.01961280
# Iteration 1159, loss = 0.01958078
# Iteration 1160, loss = 0.01954883
# Iteration 1161, loss = 0.01951696
# Iteration 1162, loss = 0.01948516
# Iteration 1163, loss = 0.01945344
# Iteration 1164, loss = 0.01942179
# Iteration 1165, loss = 0.01939021
# Iteration 1166, loss = 0.01935870
# Iteration 1167, loss = 0.01932727
# Iteration 1168, loss = 0.01929591
# Iteration 1169, loss = 0.01926463
# Iteration 1170, loss = 0.01923341
# Iteration 1171, loss = 0.01920227
# Iteration 1172, loss = 0.01917120
# Iteration 1173, loss = 0.01914020
# Iteration 1174, loss = 0.01910927
# Iteration 1175, loss = 0.01907842
# Iteration 1176, loss = 0.01904763
# Iteration 1177, loss = 0.01901692
# Iteration 1178, loss = 0.01898627
# Iteration 1179, loss = 0.01895570
# Iteration 1180, loss = 0.01892519
# Iteration 1181, loss = 0.01889476
# Iteration 1182, loss = 0.01886439
# Iteration 1183, loss = 0.01883410
# Iteration 1184, loss = 0.01880387
# Iteration 1185, loss = 0.01877372
# Iteration 1186, loss = 0.01874363
# Iteration 1187, loss = 0.01871361
# Iteration 1188, loss = 0.01868366
# Iteration 1189, loss = 0.01865377
# Iteration 1190, loss = 0.01862396
# Iteration 1191, loss = 0.01859421
# Iteration 1192, loss = 0.01856453
# Iteration 1193, loss = 0.01853492
# Iteration 1194, loss = 0.01850537
# Iteration 1195, loss = 0.01847590
# Iteration 1196, loss = 0.01844648
# Iteration 1197, loss = 0.01841714
# Iteration 1198, loss = 0.01838786
# Iteration 1199, loss = 0.01835865
# Iteration 1200, loss = 0.01832950
# Iteration 1201, loss = 0.01830042
# Iteration 1202, loss = 0.01827140
# Iteration 1203, loss = 0.01824245
# Iteration 1204, loss = 0.01821357
# Iteration 1205, loss = 0.01818475
# Iteration 1206, loss = 0.01815599
# Iteration 1207, loss = 0.01812730
# Iteration 1208, loss = 0.01809868
# Iteration 1209, loss = 0.01807011
# Iteration 1210, loss = 0.01804161
# Iteration 1211, loss = 0.01801318
# Iteration 1212, loss = 0.01798481
# Iteration 1213, loss = 0.01795650
# Iteration 1214, loss = 0.01792826
# Iteration 1215, loss = 0.01790007
# Iteration 1216, loss = 0.01787196
# Iteration 1217, loss = 0.01784390
# Iteration 1218, loss = 0.01781591
# Iteration 1219, loss = 0.01778798
# Iteration 1220, loss = 0.01776011
# Iteration 1221, loss = 0.01773230
# Iteration 1222, loss = 0.01770455
# Iteration 1223, loss = 0.01767687
# Iteration 1224, loss = 0.01764925
# Iteration 1225, loss = 0.01762168
# Iteration 1226, loss = 0.01759418
# Iteration 1227, loss = 0.01756674
# Iteration 1228, loss = 0.01753936
# Iteration 1229, loss = 0.01751205
# Iteration 1230, loss = 0.01748479
# Iteration 1231, loss = 0.01745759
# Iteration 1232, loss = 0.01743045
# Iteration 1233, loss = 0.01740337
# Iteration 1234, loss = 0.01737635
# Iteration 1235, loss = 0.01734939
# Iteration 1236, loss = 0.01732249
# Iteration 1237, loss = 0.01729565
# Iteration 1238, loss = 0.01726887
# Iteration 1239, loss = 0.01724214
# Iteration 1240, loss = 0.01721548
# Iteration 1241, loss = 0.01718887
# Iteration 1242, loss = 0.01716232
# Iteration 1243, loss = 0.01713583
# Iteration 1244, loss = 0.01710940
# Iteration 1245, loss = 0.01708302
# Iteration 1246, loss = 0.01705670
# Iteration 1247, loss = 0.01703044
# Iteration 1248, loss = 0.01700424
# Iteration 1249, loss = 0.01697809
# Iteration 1250, loss = 0.01695200
# Iteration 1251, loss = 0.01692597
# Iteration 1252, loss = 0.01689999
# Iteration 1253, loss = 0.01687407
# Iteration 1254, loss = 0.01684821
# Iteration 1255, loss = 0.01682240
# Iteration 1256, loss = 0.01679665
# Iteration 1257, loss = 0.01677095
# Iteration 1258, loss = 0.01674531
# Iteration 1259, loss = 0.01671973
# Iteration 1260, loss = 0.01669420
# Iteration 1261, loss = 0.01666872
# Iteration 1262, loss = 0.01664330
# Iteration 1263, loss = 0.01661793
# Iteration 1264, loss = 0.01659262
# Iteration 1265, loss = 0.01656737
# Iteration 1266, loss = 0.01654217
# Iteration 1267, loss = 0.01651702
# Iteration 1268, loss = 0.01649192
# Iteration 1269, loss = 0.01646688
# Iteration 1270, loss = 0.01644190
# Iteration 1271, loss = 0.01641696
# Iteration 1272, loss = 0.01639208
# Iteration 1273, loss = 0.01636726
# Iteration 1274, loss = 0.01634248
# Iteration 1275, loss = 0.01631776
# Iteration 1276, loss = 0.01629309
# Iteration 1277, loss = 0.01626848
# Iteration 1278, loss = 0.01624392
# Iteration 1279, loss = 0.01621940
# Iteration 1280, loss = 0.01619495
# Iteration 1281, loss = 0.01617054
# Iteration 1282, loss = 0.01614618
# Iteration 1283, loss = 0.01612188
# Iteration 1284, loss = 0.01609763
# Iteration 1285, loss = 0.01607343
# Iteration 1286, loss = 0.01604928
# Iteration 1287, loss = 0.01602518
# Iteration 1288, loss = 0.01600114
# Iteration 1289, loss = 0.01597714
# Iteration 1290, loss = 0.01595320
# Iteration 1291, loss = 0.01592930
# Iteration 1292, loss = 0.01590546
# Iteration 1293, loss = 0.01588166
# Iteration 1294, loss = 0.01585792
# Iteration 1295, loss = 0.01583423
# Iteration 1296, loss = 0.01581058
# Iteration 1297, loss = 0.01578699
# Iteration 1298, loss = 0.01576344
# Iteration 1299, loss = 0.01573995
# Iteration 1300, loss = 0.01571650
# Iteration 1301, loss = 0.01569311
# Iteration 1302, loss = 0.01566976
# Iteration 1303, loss = 0.01564646
# Iteration 1304, loss = 0.01562321
# Iteration 1305, loss = 0.01560001
# Iteration 1306, loss = 0.01557686
# Iteration 1307, loss = 0.01555375
# Iteration 1308, loss = 0.01553069
# Iteration 1309, loss = 0.01550769
# Iteration 1310, loss = 0.01548473
# Iteration 1311, loss = 0.01546181
# Iteration 1312, loss = 0.01543895
# Iteration 1313, loss = 0.01541613
# Iteration 1314, loss = 0.01539336
# Iteration 1315, loss = 0.01537064
# Iteration 1316, loss = 0.01534796
# Iteration 1317, loss = 0.01532533
# Iteration 1318, loss = 0.01530275
# Iteration 1319, loss = 0.01528022
# Iteration 1320, loss = 0.01525773
# Iteration 1321, loss = 0.01523529
# Iteration 1322, loss = 0.01521289
# Iteration 1323, loss = 0.01519054
# Iteration 1324, loss = 0.01516824
# Iteration 1325, loss = 0.01514598
# Iteration 1326, loss = 0.01512377
# Iteration 1327, loss = 0.01510161
# Iteration 1328, loss = 0.01507949
# Iteration 1329, loss = 0.01505741
# Iteration 1330, loss = 0.01503538
# Iteration 1331, loss = 0.01501340
# Iteration 1332, loss = 0.01499146
# Iteration 1333, loss = 0.01496957
# Iteration 1334, loss = 0.01494772
# Iteration 1335, loss = 0.01492592
# Iteration 1336, loss = 0.01490416
# Iteration 1337, loss = 0.01488244
# Iteration 1338, loss = 0.01486077
# Iteration 1339, loss = 0.01483915
# Iteration 1340, loss = 0.01481756
# Iteration 1341, loss = 0.01479603
# Iteration 1342, loss = 0.01477453
# Iteration 1343, loss = 0.01475308
# Iteration 1344, loss = 0.01473168
# Iteration 1345, loss = 0.01471031
# Iteration 1346, loss = 0.01468899
# Iteration 1347, loss = 0.01466772
# Iteration 1348, loss = 0.01464648
# Iteration 1349, loss = 0.01462529
# Iteration 1350, loss = 0.01460415
# Iteration 1351, loss = 0.01458304
# Iteration 1352, loss = 0.01456198
# Iteration 1353, loss = 0.01454096
# Iteration 1354, loss = 0.01451999
# Iteration 1355, loss = 0.01449905
# Iteration 1356, loss = 0.01447816
# Iteration 1357, loss = 0.01445731
# Iteration 1358, loss = 0.01443651
# Iteration 1359, loss = 0.01441574
# Iteration 1360, loss = 0.01439502
# Iteration 1361, loss = 0.01437434
# Iteration 1362, loss = 0.01435370
# Iteration 1363, loss = 0.01433310
# Iteration 1364, loss = 0.01431254
# Iteration 1365, loss = 0.01429202
# Iteration 1366, loss = 0.01427155
# Iteration 1367, loss = 0.01425112
# Iteration 1368, loss = 0.01423072
# Iteration 1369, loss = 0.01421037
# Iteration 1370, loss = 0.01419006
# Iteration 1371, loss = 0.01416979
# Iteration 1372, loss = 0.01414956
# Iteration 1373, loss = 0.01412937
# Iteration 1374, loss = 0.01410922
# Iteration 1375, loss = 0.01408911
# Iteration 1376, loss = 0.01406904
# Iteration 1377, loss = 0.01404901
# Iteration 1378, loss = 0.01402902
# Iteration 1379, loss = 0.01400908
# Iteration 1380, loss = 0.01398917
# Iteration 1381, loss = 0.01396930
# Iteration 1382, loss = 0.01394946
# Iteration 1383, loss = 0.01392967
# Iteration 1384, loss = 0.01390992
# Iteration 1385, loss = 0.01389021
# Iteration 1386, loss = 0.01387054
# Iteration 1387, loss = 0.01385090
# Iteration 1388, loss = 0.01383130
# Iteration 1389, loss = 0.01381175
# Iteration 1390, loss = 0.01379223
# Iteration 1391, loss = 0.01377275
# Iteration 1392, loss = 0.01375331
# Iteration 1393, loss = 0.01373390
# Iteration 1394, loss = 0.01371454
# Iteration 1395, loss = 0.01369521
# Iteration 1396, loss = 0.01367592
# Iteration 1397, loss = 0.01365667
# Iteration 1398, loss = 0.01363746
# Iteration 1399, loss = 0.01361828
# Iteration 1400, loss = 0.01359915
# Iteration 1401, loss = 0.01358005
# Iteration 1402, loss = 0.01356098
# Iteration 1403, loss = 0.01354196
# Iteration 1404, loss = 0.01352297
# Iteration 1405, loss = 0.01350402
# Iteration 1406, loss = 0.01348510
# Iteration 1407, loss = 0.01346623
# Iteration 1408, loss = 0.01344739
# Iteration 1409, loss = 0.01342858
# Iteration 1410, loss = 0.01340982
# Iteration 1411, loss = 0.01339109
# Iteration 1412, loss = 0.01337240
# Iteration 1413, loss = 0.01335374
# Iteration 1414, loss = 0.01333512
# Iteration 1415, loss = 0.01331653
# Iteration 1416, loss = 0.01329798
# Iteration 1417, loss = 0.01327947
# Iteration 1418, loss = 0.01326100
# Iteration 1419, loss = 0.01324256
# Iteration 1420, loss = 0.01322415
# Iteration 1421, loss = 0.01320578
# Iteration 1422, loss = 0.01318745
# Iteration 1423, loss = 0.01316915
# Iteration 1424, loss = 0.01315089
# Iteration 1425, loss = 0.01313266
# Iteration 1426, loss = 0.01311447
# Iteration 1427, loss = 0.01309631
# Iteration 1428, loss = 0.01307819
# Iteration 1429, loss = 0.01306010
# Iteration 1430, loss = 0.01304205
# Iteration 1431, loss = 0.01302403
# Iteration 1432, loss = 0.01300605
# Iteration 1433, loss = 0.01298810
# Iteration 1434, loss = 0.01297019
# Iteration 1435, loss = 0.01295231
# Iteration 1436, loss = 0.01293446
# Iteration 1437, loss = 0.01291665
# Iteration 1438, loss = 0.01289887
# Iteration 1439, loss = 0.01288113
# Iteration 1440, loss = 0.01286342
# Iteration 1441, loss = 0.01284575
# Iteration 1442, loss = 0.01282811
# Iteration 1443, loss = 0.01281050
# Iteration 1444, loss = 0.01279293
# ...
# Iteration 3344, loss = 0.00197989
# Iteration 3345, loss = 0.00197839
# Iteration 3346, loss = 0.00197690
# Iteration 3347, loss = 0.00197541
# Iteration 3348, loss = 0.00197392
# Iteration 3349, loss = 0.00197243
# Iteration 3350, loss = 0.00197094
# Iteration 3351, loss = 0.00196945
# Iteration 3352, loss = 0.00196797
# Iteration 3353, loss = 0.00196649
# Iteration 3354, loss = 0.00196500
# Iteration 3355, loss = 0.00196352
# Iteration 3356, loss = 0.00196204
# Iteration 3357, loss = 0.00196057
# Iteration 3358, loss = 0.00195909
# Iteration 3359, loss = 0.00195761
# Iteration 3360, loss = 0.00195614
# Iteration 3361, loss = 0.00195467
# Iteration 3362, loss = 0.00195320
# Iteration 3363, loss = 0.00195173
# Iteration 3364, loss = 0.00195026
# Iteration 3365, loss = 0.00194879
# Iteration 3366, loss = 0.00194733
# Iteration 3367, loss = 0.00194586
# Iteration 3368, loss = 0.00194440
# Iteration 3369, loss = 0.00194294
# Iteration 3370, loss = 0.00194148
# Iteration 3371, loss = 0.00194002
# Iteration 3372, loss = 0.00193856
# Iteration 3373, loss = 0.00193711
# Iteration 3374, loss = 0.00193565
# Iteration 3375, loss = 0.00193420
# Iteration 3376, loss = 0.00193275
# Iteration 3377, loss = 0.00193130
# Iteration 3378, loss = 0.00192985
# Iteration 3379, loss = 0.00192840
# Iteration 3380, loss = 0.00192696
# Iteration 3381, loss = 0.00192551
# Iteration 3382, loss = 0.00192407
# Iteration 3383, loss = 0.00192263
# Iteration 3384, loss = 0.00192118
# Iteration 3385, loss = 0.00191975
# Iteration 3386, loss = 0.00191831
# Iteration 3387, loss = 0.00191687
# Iteration 3388, loss = 0.00191544
# Iteration 3389, loss = 0.00191400
# Iteration 3390, loss = 0.00191257
# Iteration 3391, loss = 0.00191114
# Iteration 3392, loss = 0.00190971
# Iteration 3393, loss = 0.00190828
# Iteration 3394, loss = 0.00190685
# Iteration 3395, loss = 0.00190543
# Iteration 3396, loss = 0.00190400
# Iteration 3397, loss = 0.00190258
# Iteration 3398, loss = 0.00190116
# Iteration 3399, loss = 0.00189974
# Iteration 3400, loss = 0.00189832
# Iteration 3401, loss = 0.00189690
# Iteration 3402, loss = 0.00189548
# Iteration 3403, loss = 0.00189407
# Iteration 3404, loss = 0.00189265
# Iteration 3405, loss = 0.00189124
# Iteration 3406, loss = 0.00188983
# Iteration 3407, loss = 0.00188842
# Iteration 3408, loss = 0.00188701
# Iteration 3409, loss = 0.00188560
# Iteration 3410, loss = 0.00188420
# Iteration 3411, loss = 0.00188279
# Iteration 3412, loss = 0.00188139
# Iteration 3413, loss = 0.00187999
# Iteration 3414, loss = 0.00187859
# Iteration 3415, loss = 0.00187719
# Iteration 3416, loss = 0.00187579
# Iteration 3417, loss = 0.00187439
# Iteration 3418, loss = 0.00187300
# Iteration 3419, loss = 0.00187160
# Iteration 3420, loss = 0.00187021
# Iteration 3421, loss = 0.00186882
# Iteration 3422, loss = 0.00186743
# Iteration 3423, loss = 0.00186604
# Iteration 3424, loss = 0.00186465
# Iteration 3425, loss = 0.00186327
# Iteration 3426, loss = 0.00186188
# Iteration 3427, loss = 0.00186050
# Iteration 3428, loss = 0.00185911
# Iteration 3429, loss = 0.00185773
# Iteration 3430, loss = 0.00185635
# Iteration 3431, loss = 0.00185497
# Iteration 3432, loss = 0.00185360
# Iteration 3433, loss = 0.00185222
# Iteration 3434, loss = 0.00185085
# Iteration 3435, loss = 0.00184947
# Iteration 3436, loss = 0.00184810
# Iteration 3437, loss = 0.00184673
# Iteration 3438, loss = 0.00184536
# Iteration 3439, loss = 0.00184399
# Iteration 3440, loss = 0.00184262
# Iteration 3441, loss = 0.00184126
# Iteration 3442, loss = 0.00183989
# Iteration 3443, loss = 0.00183853
# Iteration 3444, loss = 0.00183717
# Iteration 3445, loss = 0.00183581
# Iteration 3446, loss = 0.00183445
# Iteration 3447, loss = 0.00183309
# Iteration 3448, loss = 0.00183173
# Iteration 3449, loss = 0.00183038
# Iteration 3450, loss = 0.00182902
# Iteration 3451, loss = 0.00182767
# Iteration 3452, loss = 0.00182632
# Iteration 3453, loss = 0.00182497
# Iteration 3454, loss = 0.00182362
# Iteration 3455, loss = 0.00182227
# Iteration 3456, loss = 0.00182092
# Iteration 3457, loss = 0.00181958
# Iteration 3458, loss = 0.00181823
# Iteration 3459, loss = 0.00181689
# Iteration 3460, loss = 0.00181555
# Iteration 3461, loss = 0.00181421
# Iteration 3462, loss = 0.00181287
# Iteration 3463, loss = 0.00181153
# Iteration 3464, loss = 0.00181019
# Iteration 3465, loss = 0.00180886
# Iteration 3466, loss = 0.00180752
# Iteration 3467, loss = 0.00180619
# Iteration 3468, loss = 0.00180486
# Iteration 3469, loss = 0.00180353
# Iteration 3470, loss = 0.00180220
# Iteration 3471, loss = 0.00180087
# Iteration 3472, loss = 0.00179954
# Iteration 3473, loss = 0.00179822
# Iteration 3474, loss = 0.00179689
# Iteration 3475, loss = 0.00179557
# Iteration 3476, loss = 0.00179425
# Iteration 3477, loss = 0.00179293
# Iteration 3478, loss = 0.00179161
# Iteration 3479, loss = 0.00179029
# Iteration 3480, loss = 0.00178897
# Iteration 3481, loss = 0.00178765
# Iteration 3482, loss = 0.00178634
# Iteration 3483, loss = 0.00178502
# Iteration 3484, loss = 0.00178371
# Iteration 3485, loss = 0.00178240
# Iteration 3486, loss = 0.00178109
# Iteration 3487, loss = 0.00177978
# Iteration 3488, loss = 0.00177847
# Iteration 3489, loss = 0.00177717
# Iteration 3490, loss = 0.00177586
# Iteration 3491, loss = 0.00177456
# Iteration 3492, loss = 0.00177326
# Iteration 3493, loss = 0.00177195
# Iteration 3494, loss = 0.00177065
# Iteration 3495, loss = 0.00176936
# Iteration 3496, loss = 0.00176806
# Iteration 3497, loss = 0.00176676
# Iteration 3498, loss = 0.00176546
# Iteration 3499, loss = 0.00176417
# Iteration 3500, loss = 0.00176288
# Iteration 3501, loss = 0.00176159
# Iteration 3502, loss = 0.00176029
# Iteration 3503, loss = 0.00175900
# Iteration 3504, loss = 0.00175772
# Iteration 3505, loss = 0.00175643
# Iteration 3506, loss = 0.00175514
# Iteration 3507, loss = 0.00175386
# Iteration 3508, loss = 0.00175257
# Iteration 3509, loss = 0.00175129
# Iteration 3510, loss = 0.00175001
# Iteration 3511, loss = 0.00174873
# Iteration 3512, loss = 0.00174745
# Iteration 3513, loss = 0.00174617
# Iteration 3514, loss = 0.00174490
# Iteration 3515, loss = 0.00174362
# Iteration 3516, loss = 0.00174235
# Iteration 3517, loss = 0.00174107
# Iteration 3518, loss = 0.00173980
# Iteration 3519, loss = 0.00173853
# Iteration 3520, loss = 0.00173726
# Iteration 3521, loss = 0.00173599
# Iteration 3522, loss = 0.00173472
# Iteration 3523, loss = 0.00173346
# Iteration 3524, loss = 0.00173219
# Iteration 3525, loss = 0.00173093
# Iteration 3526, loss = 0.00172967
# Iteration 3527, loss = 0.00172841
# Iteration 3528, loss = 0.00172714
# Iteration 3529, loss = 0.00172589
# Iteration 3530, loss = 0.00172463
# Iteration 3531, loss = 0.00172337
# Iteration 3532, loss = 0.00172211
# Iteration 3533, loss = 0.00172086
# Iteration 3534, loss = 0.00171961
# Iteration 3535, loss = 0.00171835
# Iteration 3536, loss = 0.00171710
# Iteration 3537, loss = 0.00171585
# Iteration 3538, loss = 0.00171460
# Iteration 3539, loss = 0.00171336
# Iteration 3540, loss = 0.00171211
# Iteration 3541, loss = 0.00171086
# Iteration 3542, loss = 0.00170962
# Iteration 3543, loss = 0.00170838
# Iteration 3544, loss = 0.00170713
# Iteration 3545, loss = 0.00170589
# Iteration 3546, loss = 0.00170465
# Iteration 3547, loss = 0.00170341
# Iteration 3548, loss = 0.00170218
# Iteration 3549, loss = 0.00170094
# Iteration 3550, loss = 0.00169970
# Iteration 3551, loss = 0.00169847
# Iteration 3552, loss = 0.00169724
# Iteration 3553, loss = 0.00169601
# Iteration 3554, loss = 0.00169477
# Iteration 3555, loss = 0.00169354
# Iteration 3556, loss = 0.00169232
# Iteration 3557, loss = 0.00169109
# Iteration 3558, loss = 0.00168986
# Iteration 3559, loss = 0.00168864
# Iteration 3560, loss = 0.00168741
# Iteration 3561, loss = 0.00168619
# Iteration 3562, loss = 0.00168497
# Iteration 3563, loss = 0.00168375
# Iteration 3564, loss = 0.00168253
# Iteration 3565, loss = 0.00168131
# Iteration 3566, loss = 0.00168009
# Iteration 3567, loss = 0.00167887
# Iteration 3568, loss = 0.00167766
# Iteration 3569, loss = 0.00167644
# Iteration 3570, loss = 0.00167523
# Iteration 3571, loss = 0.00167402
# Iteration 3572, loss = 0.00167281
# Iteration 3573, loss = 0.00167160
# Iteration 3574, loss = 0.00167039
# Iteration 3575, loss = 0.00166918
# Iteration 3576, loss = 0.00166798
# Iteration 3577, loss = 0.00166677
# Iteration 3578, loss = 0.00166557
# Iteration 3579, loss = 0.00166436
# Iteration 3580, loss = 0.00166316
# Iteration 3581, loss = 0.00166196
# Iteration 3582, loss = 0.00166076
# Iteration 3583, loss = 0.00165956
# Iteration 3584, loss = 0.00165836
# Iteration 3585, loss = 0.00165717
# Iteration 3586, loss = 0.00165597
# Iteration 3587, loss = 0.00165478
# Iteration 3588, loss = 0.00165358
# Iteration 3589, loss = 0.00165239
# Iteration 3590, loss = 0.00165120
# Iteration 3591, loss = 0.00165001
# Iteration 3592, loss = 0.00164882
# Iteration 3593, loss = 0.00164763
# Iteration 3594, loss = 0.00164644
# Iteration 3595, loss = 0.00164526
# Iteration 3596, loss = 0.00164407
# Iteration 3597, loss = 0.00164289
# Iteration 3598, loss = 0.00164171
# Iteration 3599, loss = 0.00164052
# Iteration 3600, loss = 0.00163934
# Iteration 3601, loss = 0.00163816
# Iteration 3602, loss = 0.00163699
# Iteration 3603, loss = 0.00163581
# Iteration 3604, loss = 0.00163463
# Iteration 3605, loss = 0.00163346
# Iteration 3606, loss = 0.00163228
# Iteration 3607, loss = 0.00163111
# Iteration 3608, loss = 0.00162994
# Iteration 3609, loss = 0.00162877
# Iteration 3610, loss = 0.00162760
# Iteration 3611, loss = 0.00162643
# Iteration 3612, loss = 0.00162526
# Iteration 3613, loss = 0.00162409
# Iteration 3614, loss = 0.00162293
# Iteration 3615, loss = 0.00162176
# Iteration 3616, loss = 0.00162060
# Iteration 3617, loss = 0.00161943
# Iteration 3618, loss = 0.00161827
# Iteration 3619, loss = 0.00161711
# Iteration 3620, loss = 0.00161595
# Iteration 3621, loss = 0.00161479
# Iteration 3622, loss = 0.00161364
# Iteration 3623, loss = 0.00161248
# Iteration 3624, loss = 0.00161132
# Iteration 3625, loss = 0.00161017
# Iteration 3626, loss = 0.00160902
# Iteration 3627, loss = 0.00160786
# Iteration 3628, loss = 0.00160671
# Iteration 3629, loss = 0.00160556
# Iteration 3630, loss = 0.00160441
# Iteration 3631, loss = 0.00160327
# Iteration 3632, loss = 0.00160212
# Iteration 3633, loss = 0.00160097
# Iteration 3634, loss = 0.00159983
# Iteration 3635, loss = 0.00159868
# Iteration 3636, loss = 0.00159754
# Iteration 3637, loss = 0.00159640
# Iteration 3638, loss = 0.00159526
# Iteration 3639, loss = 0.00159412
# Iteration 3640, loss = 0.00159298
# Iteration 3641, loss = 0.00159184
# Iteration 3642, loss = 0.00159070
# Iteration 3643, loss = 0.00158957
# Iteration 3644, loss = 0.00158843
# Iteration 3645, loss = 0.00158730
# Iteration 3646, loss = 0.00158616
# Iteration 3647, loss = 0.00158503
# Iteration 3648, loss = 0.00158390
# Iteration 3649, loss = 0.00158277
# Iteration 3650, loss = 0.00158164
# Iteration 3651, loss = 0.00158052
# Iteration 3652, loss = 0.00157939
# Iteration 3653, loss = 0.00157826
# Iteration 3654, loss = 0.00157714
# Iteration 3655, loss = 0.00157601
# Iteration 3656, loss = 0.00157489
# Iteration 3657, loss = 0.00157377
# Iteration 3658, loss = 0.00157265
# Iteration 3659, loss = 0.00157153
# Iteration 3660, loss = 0.00157041
# Iteration 3661, loss = 0.00156929
# Iteration 3662, loss = 0.00156818
# Iteration 3663, loss = 0.00156706
# Iteration 3664, loss = 0.00156594
# Iteration 3665, loss = 0.00156483
# Iteration 3666, loss = 0.00156372
# Iteration 3667, loss = 0.00156261
# Iteration 3668, loss = 0.00156149
# Iteration 3669, loss = 0.00156038
# Iteration 3670, loss = 0.00155928
# Iteration 3671, loss = 0.00155817
# Iteration 3672, loss = 0.00155706
# Iteration 3673, loss = 0.00155596
# Iteration 3674, loss = 0.00155485
# Iteration 3675, loss = 0.00155375
# Iteration 3676, loss = 0.00155264
# Iteration 3677, loss = 0.00155154
# Iteration 3678, loss = 0.00155044
# Iteration 3679, loss = 0.00154934
# Iteration 3680, loss = 0.00154824
# Iteration 3681, loss = 0.00154714
# Iteration 3682, loss = 0.00154605
# Iteration 3683, loss = 0.00154495
# Iteration 3684, loss = 0.00154385
# Iteration 3685, loss = 0.00154276
# Iteration 3686, loss = 0.00154167
# Iteration 3687, loss = 0.00154057
# Iteration 3688, loss = 0.00153948
# Iteration 3689, loss = 0.00153839
# Iteration 3690, loss = 0.00153730
# Iteration 3691, loss = 0.00153621
# Iteration 3692, loss = 0.00153513
# Iteration 3693, loss = 0.00153404
# Iteration 3694, loss = 0.00153296
# Iteration 3695, loss = 0.00153187
# Iteration 3696, loss = 0.00153079
# Iteration 3697, loss = 0.00152970
# Iteration 3698, loss = 0.00152862
# Iteration 3699, loss = 0.00152754
# Iteration 3700, loss = 0.00152646
# Iteration 3701, loss = 0.00152538
# Iteration 3702, loss = 0.00152431
# Iteration 3703, loss = 0.00152323
# Iteration 3704, loss = 0.00152215
# Iteration 3705, loss = 0.00152108
# Iteration 3706, loss = 0.00152000
# Iteration 3707, loss = 0.00151893
# Iteration 3708, loss = 0.00151786
# Iteration 3709, loss = 0.00151679
# Iteration 3710, loss = 0.00151572
# Iteration 3711, loss = 0.00151465
# Iteration 3712, loss = 0.00151358
# Iteration 3713, loss = 0.00151251
# Iteration 3714, loss = 0.00151144
# Iteration 3715, loss = 0.00151038
# Iteration 3716, loss = 0.00150931
# Iteration 3717, loss = 0.00150825
# Iteration 3718, loss = 0.00150719
# Iteration 3719, loss = 0.00150613
# Iteration 3720, loss = 0.00150507
# Iteration 3721, loss = 0.00150401
# Iteration 3722, loss = 0.00150295
# Iteration 3723, loss = 0.00150189
# Iteration 3724, loss = 0.00150083
# Iteration 3725, loss = 0.00149977
# Iteration 3726, loss = 0.00149872
# Iteration 3727, loss = 0.00149767
# Iteration 3728, loss = 0.00149661
# Iteration 3729, loss = 0.00149556
# Iteration 3730, loss = 0.00149451
# Iteration 3731, loss = 0.00149346
# Iteration 3732, loss = 0.00149241
# Iteration 3733, loss = 0.00149136
# Iteration 3734, loss = 0.00149031
# Iteration 3735, loss = 0.00148926
# Iteration 3736, loss = 0.00148822
# Iteration 3737, loss = 0.00148717
# Iteration 3738, loss = 0.00148613
# Iteration 3739, loss = 0.00148508
# Iteration 3740, loss = 0.00148404
# Iteration 3741, loss = 0.00148300
# Iteration 3742, loss = 0.00148196
# Iteration 3743, loss = 0.00148092
# Iteration 3744, loss = 0.00147988
# Iteration 3745, loss = 0.00147884
# Iteration 3746, loss = 0.00147781
# Iteration 3747, loss = 0.00147677
# Iteration 3748, loss = 0.00147574
# Iteration 3749, loss = 0.00147470
# Iteration 3750, loss = 0.00147367
# Iteration 3751, loss = 0.00147264
# Iteration 3752, loss = 0.00147160
# Iteration 3753, loss = 0.00147057
# Iteration 3754, loss = 0.00146954
# Iteration 3755, loss = 0.00146852
# Iteration 3756, loss = 0.00146749
# Iteration 3757, loss = 0.00146646
# Iteration 3758, loss = 0.00146543
# Iteration 3759, loss = 0.00146441
# Iteration 3760, loss = 0.00146338
# Iteration 3761, loss = 0.00146236
# Iteration 3762, loss = 0.00146134
# Iteration 3763, loss = 0.00146032
# Iteration 3764, loss = 0.00145930
# Iteration 3765, loss = 0.00145828
# Iteration 3766, loss = 0.00145726
# Iteration 3767, loss = 0.00145624
# Iteration 3768, loss = 0.00145522
# Iteration 3769, loss = 0.00145421
# Iteration 3770, loss = 0.00145319
# Iteration 3771, loss = 0.00145218
# Iteration 3772, loss = 0.00145116
# Iteration 3773, loss = 0.00145015
# Iteration 3774, loss = 0.00144914
# Iteration 3775, loss = 0.00144813
# Iteration 3776, loss = 0.00144712
# Iteration 3777, loss = 0.00144611
# Iteration 3778, loss = 0.00144510
# Iteration 3779, loss = 0.00144409
# Iteration 3780, loss = 0.00144309
# Iteration 3781, loss = 0.00144208
# Iteration 3782, loss = 0.00144108
# Iteration 3783, loss = 0.00144007
# Iteration 3784, loss = 0.00143907
# Iteration 3785, loss = 0.00143807
# Iteration 3786, loss = 0.00143706
# Iteration 3787, loss = 0.00143606
# Iteration 3788, loss = 0.00143506
# Iteration 3789, loss = 0.00143407
# Iteration 3790, loss = 0.00143307
# Iteration 3791, loss = 0.00143207
# Iteration 3792, loss = 0.00143108
# Iteration 3793, loss = 0.00143008
# Iteration 3794, loss = 0.00142909
# Iteration 3795, loss = 0.00142809
# Iteration 3796, loss = 0.00142710
# Iteration 3797, loss = 0.00142611
# Iteration 3798, loss = 0.00142512
# Training loss did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# accuracy for test data: 46.30%
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        25
#            2       0.95      0.95      0.95        21
#            3       0.88      0.88      0.88         8
#
#     accuracy                           0.96        54
#    macro avg       0.94      0.94      0.94        54
# weighted avg       0.96      0.96      0.96        54

# %% [markdown]
# 繪製訓練曲線：訓練過程的誤差會隨著演算法的遞迴與迭代的增加，觀察其逐漸變小的趨勢。

# %%
fig = plt.figure(figsize=(6, 3))
plt.plot(clf_MLP.loss_curve_)
plt.grid(True)
plt.title('Training Loss Curve')
plt.xlabel('Iter.')
plt.ylabel('Fitting Loss')
plt.show()

# %% [markdown]
# 繪製混淆矩陣 Confusion matrix，觀察不同群組的分類表現

# %%
# Confusion matrix
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
# Confusion matrix
title = 'Testing score ={:.2f}%'.format(100*clf_MLP.score(X_test_, y_test))
disp = ConfusionMatrixDisplay.from_estimator(
        clf_MLP,
        X_test_,
        y_test,
        xticks_rotation=45, #'vertical',
        # display_labels=class_names,
        cmap=plt.cm.Blues,
        normalize='true',
        ax = ax
    )
disp.ax_.set_title(title)
# plot_confusion_matrix(clf, X_test, y_test,
#     cmap = plt.cm.Blues, normalize = 'true')  # normalize='false' to show numbers
# plt.title('Testing score ={:.2f}%'.format(100*clf.score(X_test, y_test)))
plt.show()

# %% [markdown]
# <font color=yellow>最佳組合選擇 by GridSearchCV</font>
#
# CV: Cross Validation

# %%
from sklearn.model_selection import  GridSearchCV, \
                        StratifiedShuffleSplit
from datetime import datetime

# Get the current date and time
now = datetime.now()
# Format the date and time as a string
now_str = now.strftime("%Y_%m_%d_%H_%M_%S")
results_file = 'data/results_' + now_str + '.csv'

opts = dict(tol = 1e-6, max_iter = int(1e6)) # parameters for LogisticRegression
parameters = {'solver':['lbfgs', 'newton-cg', 'sag', 'saga'], \
              'C':[0.1, 1, 10]} # parameters for GridSearchCV
# parameters = {'solver':['lbfgs', 'liblinear', 'newton-cg',\
#                         'sag','saga']}
cv = StratifiedShuffleSplit(n_splits=5, test_size=0.3, \
                            random_state=0) # 5-fold CV
grid = GridSearchCV(estimator=LogisticRegression(**opts), \
                param_grid=parameters, cv=cv, 
                scoring=['accuracy','f1_macro'], refit="accuracy")
grid.fit(X_train_, y_train)
cv_logistic = pd.DataFrame(data = grid.cv_results_)
cv_logistic.to_csv(results_file)
print(grid.best_params_)
print(grid.best_score_)
print(grid.best_estimator_)
# Out:
# {'C': 0.1, 'solver': 'lbfgs'}
# 1.0
# LogisticRegression(C=0.1, max_iter=1000000, tol=1e-06)
